# %%
import pandas as pd
import pickle

# %%
df = pd.read_csv('Austin_reviews.csv')
# Out:
# /tmp/ipykernel_228814/3853135698.py:1: DtypeWarning: Columns (1,2,3,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Austin_reviews.csv')

# %%
df_count = df.groupby('business_id').count()
df_count
# Out:
#                                                     review_id  user id  stars  \
# business_id
#                                                             0        0      0
#  Buen Provecho!                                             1        1      1
#  JCTSFR: 8.16                                               1        1      1
#  On my next trip to Austin I definitely plan on...          1        1      1
#  Service here is pretty friendly and from what ...          1        1      1
# ...                                                       ...      ...    ...
# ztEZF1u_JJa8fVOLjftgTQ                                     52       52     52
# ztqAoS8uPQ0CFmqTO3s6gA                                     37       37     37
# zyHMtStYlKG67WRprp6GZQ                                    269      269    269
# zy_C-wrNYaypkwZnFz7yLQ                                     75       75     75
# zyryFZQYCPF5NDFXDeUHuQ                                     17       17     17
#
# ...

# %%
df_plus = df_count[df_count.review_id >= 100]
df_plus
# Out:
#                         review_id  user id  stars  review_date  text  name  \
# business_id
# --164t1nclzzmca7eDiJMw        147      147    147          147   147   147
# -1ShItlulHnBsoOQWnblzw        106      106    106          106   106   106
# -4ofMtrD7pSpZIX5pnDkig       1474     1474   1474         1474  1474  1474
# -85pDrVcAdzNK55bFpintg        381      381    381          381   381   381
# -9GunsagWEkoxOpxIX2feQ        109      109    109          109   109   109
# ...                           ...      ...    ...          ...   ...   ...
# zerPYZ-lid5CG27a1-7YMw        223      223    223          223   223   223
# zgLCiq239ztOrbFoeLoJfw        129      129    129          129   129   129
# zlPKCqb9sfkhIW27sAGsIA        104      104    104          104   104   104
# zr40jIjFDIcZ3dzbSK53Ww        114      114    114          114   114   114
# zyHMtStYlKG67WRprp6GZQ        269      269    269          269   269   269
#
# ...

# %%
# !ls Atlanta_trainValidTest
# Out:
# labels.pickle

# %%
with open("Austin_trainValidTest/labels.pickle", "rb") as f:
    x = pickle.load(f)

# %%
print(x)
# Out:
# ['g3pXGPRKYd_WQxLT2IFPxQ', 'cmFvz2m5NIyq9PAo4-qCGA', 'xwHhz09uHHTuxJiuRbaS6Q', 'pp73b2zGEwRbwSgYYvB2Dg', '_I-gzz4FEuU2XBygdWP7SA', '6fyO3NxbqTVoSYjmcjNCFA', '_BbODcinangkwNvVwpvfuA', 'bZiIIUcpgxh8mpKMDhdqbA', 'CjvV9PzdSOk7gapnwS1Xww', 'XRq1pxoeTIUhTPVUNgDErQ', '6nNseNdeC6QTKa6XloL3zg', 'Tv0_XqTtO3kcnbqGrgLPJQ', 'ojHIGVvaz3koIzgnrCb21Q', '4O4TaNMBlzkwmte7yuxh4Q', '0m9yum2bqMCQtxbHuQbQFw', 'eAifnc03bdAKyGN0MZm6_g', 'k9TCLGRS9Igci2dj6qlmZA', '8l0zeJCRfAL8BYrnDxPcJQ', 'CqOkl94q9ttvYNWIITA8ow', 'Q5MBVuaK3-lL1jSUhmNaFw', 'YrVFPxvu4hQnHQNWcqsTUg', '--164t1nclzzmca7eDiJMw', 'cZzN8lIgiHacCnjrtI7cHw', 'XNrAtQFU4vl9NA8GTlNonA', 'Xa4YAhSdEie3Qp6AK8QN7g', 'XjC5H-uKRrsctioXxuCMQQ', 'XrPB1j9LKRPSwg7TYaZzcA', '54mjQweIUsvE3dnco83PEg', 'AKmD2-SgVaHAltP8lLzavA', 'bJbJyH6sZeltbBIbe32R8g', 'cs6HfZNykLVitm09jWFqWg', 'pKXtSuabMA63tYCk1UMR-g', 'GruGgKqo15Jpl9n7IDwU5A', 'QJoj9AMBYBT9ojq2xMQ9Zg', 'Tta8AYBZq3fwr1n2up75vQ', 'HnyCxHXrCuZnlemW_1FrKw', 'bkIqMlmP1phbHxhfUyTcrQ', 'qbD1wSEGk7_wcFGIDmbqvw', 'EmIpleat
# ...

# %%
df_select = df_count[df_count.index.isin(x)]

# %%
df_select
# Out:
#                         review_id  user id  stars  review_date  text  name  \
# business_id
# --164t1nclzzmca7eDiJMw        147      147    147          147   147   147
# -1ShItlulHnBsoOQWnblzw        106      106    106          106   106   106
# -4cQ12xutjNLW-tPI06_tg         86       86     86           86    86    86
# -4ofMtrD7pSpZIX5pnDkig       1474     1474   1474         1474  1474  1474
# -85pDrVcAdzNK55bFpintg        381      381    381          381   381   381
# ...                           ...      ...    ...          ...   ...   ...
# zjbDNFQl8peTHZNPzpYjow         60       60     60           60    60    60
# zlPKCqb9sfkhIW27sAGsIA        104      104    104          104   104   104
# zr40jIjFDIcZ3dzbSK53Ww        114      114    114          114   114   114
# zyHMtStYlKG67WRprp6GZQ        269      269    269          269   269   269
# zy_C-wrNYaypkwZnFz7yLQ         75       75     75           75    75    75
#
# ...

# %%
df_select.min()
# Out:
# review_id      60
# user id        60
# stars          60
# review_date    60
# text           60
# name           60
# categories     60
# address        60
# postal code    60
# price          60
# text_length    60
# dtype: int64

# %%
df_plus = df_count[df_count.review_id >= 60]
df_plus
# Out:
#                         review_id  user id  stars  review_date  text  name  \
# business_id
# --164t1nclzzmca7eDiJMw        147      147    147          147   147   147
# -1ShItlulHnBsoOQWnblzw        106      106    106          106   106   106
# -4cQ12xutjNLW-tPI06_tg         86       86     86           86    86    86
# -4ofMtrD7pSpZIX5pnDkig       1474     1474   1474         1474  1474  1474
# -85pDrVcAdzNK55bFpintg        381      381    381          381   381   381
# ...                           ...      ...    ...          ...   ...   ...
# zjbDNFQl8peTHZNPzpYjow         60       60     60           60    60    60
# zlPKCqb9sfkhIW27sAGsIA        104      104    104          104   104   104
# zr40jIjFDIcZ3dzbSK53Ww        114      114    114          114   114   114
# zyHMtStYlKG67WRprp6GZQ        269      269    269          269   269   269
# zy_C-wrNYaypkwZnFz7yLQ         75       75     75           75    75    75
#
# ...
