# %%
import pandas as pd
import pickle

# %%
df = pd.read_csv('Atlanta_reviews.csv')
# Out:
# /tmp/ipykernel_224043/3400485270.py:1: DtypeWarning: Columns (1,2,3,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Atlanta_reviews.csv')

# %%
df_count = df.groupby('business_id').count()
df_count
# Out:
#                                                     review_id  user id  stars  \
# business_id
#                                                             0        0      0
#  A. I was starving and it was sometime between ...          0        0      0
#  B. I usually went with a pretty good buzz                  0        0      0
#  C. I was usually with a bunch of friends                   0        0      0
#  D. I was young and unruly.                                 0        0      0
# ...                                                       ...      ...    ...
# zy75CWA_oJYEhtXz8OOQsg                                     94       94     94
# zyYNLYUVabUXkwq___Q3ug                                     27       27     27
# zylYdVSB_KCGsB-Vunncsw                                     32       32     32
# zzin1d1oHi81GuI0ufo1VA                                    656      656    656
# zzlkjDG9Rv8Jn-vSolMgyw                                    120      120    120
#
#                                                     review_date  text  name  \
# business_id
#                                                               0     0     0
#  A. I was starving and it was sometime between ...            0     0     0
#  B. I usually went with a pretty good buzz                    0     0     0
#  C. I was usually with a bunch of friends                     0     0     0
#  D. I was young and unruly.                                   0     0     0
# ...                                                         ...   ...   ...
# zy75CWA_oJYEhtXz8OOQsg                                       94    94    94
# zyYNLYUVabUXkwq___Q3ug                                       27    27    27
# zylYdVSB_KCGsB-Vunncsw                                       32    32    32
# zzin1d1oHi81GuI0ufo1VA                                      656   656   656
# zzlkjDG9Rv8Jn-vSolMgyw                                      120   120   120
#
#                                                     categories  address  \
# business_id
#                                                              0        0
#  A. I was starving and it was sometime between ...           0        0
#  B. I usually went with a pretty good buzz                   0        0
#  C. I was usually with a bunch of friends                    0        0
#  D. I was young and unruly.                                  0        0
# ...                                                        ...      ...
# zy75CWA_oJYEhtXz8OOQsg                                      94       94
# zyYNLYUVabUXkwq___Q3ug                                      27       27
# zylYdVSB_KCGsB-Vunncsw                                      32       32
# zzin1d1oHi81GuI0ufo1VA                                     656      656
# zzlkjDG9Rv8Jn-vSolMgyw                                     120      120
#
#                                                     postal code  price  \
# business_id
#                                                               0      0
#  A. I was starving and it was sometime between ...            0      0
#  B. I usually went with a pretty good buzz                    0      0
#  C. I was usually with a bunch of friends                     0      0
#  D. I was young and unruly.                                   0      0
# ...                                                         ...    ...
# zy75CWA_oJYEhtXz8OOQsg                                       94     94
# zyYNLYUVabUXkwq___Q3ug                                       27     27
# zylYdVSB_KCGsB-Vunncsw                                       32     32
# zzin1d1oHi81GuI0ufo1VA                                      656    656
# zzlkjDG9Rv8Jn-vSolMgyw                                      120    120
#
#                                                     text_length
# business_id
#                                                               0
#  A. I was starving and it was sometime between ...            0
#  B. I usually went with a pretty good buzz                    0
#  C. I was usually with a bunch of friends                     0
#  D. I was young and unruly.                                   0
# ...                                                         ...
# zy75CWA_oJYEhtXz8OOQsg                                       94
# zyYNLYUVabUXkwq___Q3ug                                       27
# zylYdVSB_KCGsB-Vunncsw                                       32
# zzin1d1oHi81GuI0ufo1VA                                      656
# zzlkjDG9Rv8Jn-vSolMgyw                                      120
#
# [3691 rows x 11 columns]

# %%
df_plus = df_count[df_count.review_id >= 100]
df_plus
# Out:
#                         review_id  user id  stars  review_date  text  name  \
# business_id
# -5VyAi8GR34xmDAgFZTitg        437      437    437          437   437   437
# -9Wf7fUFcwC-3gEBc9iapw        116      116    116          116   116   116
# -AIX1rem_OF-9Et3p_K9Gg        335      335    335          335   335   335
# -CHazLwo2j2G8gWEZN53hA        824      824    824          824   824   824
# -DISJqPp4zcDVw7R-MOjog        207      207    207          207   207   207
# ...                           ...      ...    ...          ...   ...   ...
# zpKvO2SOXHV9cxvBm6q4Fg        203      203    203          203   203   203
# zpOcXfa6bbW6AG5L60UL_A        207      207    207          207   207   207
# ztY4uPNUTWMN9LT3L5mD3Q        828      828    828          828   828   828
# zzin1d1oHi81GuI0ufo1VA        656      656    656          656   656   656
# zzlkjDG9Rv8Jn-vSolMgyw        120      120    120          120   120   120
#
#                         categories  address  postal code  price  text_length
# business_id
# -5VyAi8GR34xmDAgFZTitg         437      437          437    437          437
# -9Wf7fUFcwC-3gEBc9iapw         116      116          116    116          116
# -AIX1rem_OF-9Et3p_K9Gg         335      335          335    335          335
# -CHazLwo2j2G8gWEZN53hA         824      824          824    824          824
# -DISJqPp4zcDVw7R-MOjog         207      207          207    207          207
# ...                            ...      ...          ...    ...          ...
# zpKvO2SOXHV9cxvBm6q4Fg         203      203          203    203          203
# zpOcXfa6bbW6AG5L60UL_A         207      207          207    207          207
# ztY4uPNUTWMN9LT3L5mD3Q         828      828          828    828          828
# zzin1d1oHi81GuI0ufo1VA         656      656          656    656          656
# zzlkjDG9Rv8Jn-vSolMgyw         120      120          120    120          120
#
# [1496 rows x 11 columns]

# %%
# !ls Atlanta_trainValidTest
# Out:
# labels.pickle

# %%
with open("Atlanta_trainValidTest/labels.pickle", "rb") as f:
    x = pickle.load(f)

# %%
print(x)
# Out:
# ['skJ7MuoT1YZq1WfILiCtwA', '79q-68qffx-1fYfmGwr2Hw', 'Ln-8CbKGZGmF-GCqMoMcpA', '-lPbwmwui7oKkSEAqqClGg', 'eMJGDVzTH7mbGNWIfz6jcQ', 'LCuqEMs-2MiR7ilr66o_Kw', 'usob9YcE7rhpJcaCwv5J_Q', 'CxQ1m2iY4wQpXC64tSfWgQ', 'EmJOkTKIwgm7QJbls7hN3w', '2PoL_ddoYm9KbdDw2A5K3A', '83maS2mCXYZjuwEhozVtLA', 'vFulipMlcFyN60_SyAhjyA', 'd-Gv5j_7aANsX0kYyOYQ9w', 'HhYxrJ0u3ROL-iwo5VFfZA', 'KR2yq1GAAeH8Ozg1CS2dJg', 'C_TpeAY3bGZU8yXMpLNeqA', 'TA1KUSCu8GkWP9w0rmElxw', 'z9oCxeqOKp2QMfM24m7bUw', 'LGZimmjxbfGwBHgPZCx5cQ', '-C
NQ1dgkA', 'WziqGmt6LHfwfbh_R3aJug', 'n5rzkm98n_HWPPS8PQiOMQ', 'i3tJgf3BhAej354EhrK7yg', 'AvXqLbcGCxdIEF_qZTY0Kw', 'D-_DMNa4O1C0Cz-WCZwZYQ', 'Kcva2t7e6Ukpb5vMvkdc2w', '2VTUvyDnORl1agrRR2qUSQ', '8OFReJh0DYeAQYI40_Q8hA', 'Y2R-8nnUNulCYYWVXaEGAA', '3ejW1TGlpSVhaspKversrw', '32m-nMxWAO9E5ZO-WbY_SA', 'G4egWE5WINCQhJXKbgFEEQ', 'SuA90sXOd6Jw9W_Bz6P1 ...

# %%
df_select = df_count[df_count.index.isin(x)]

# %%
df_select
# Out:
#                         review_id  user id  stars  review_date  text  name  \
# business_id
# -4P7VlKa9n-TwOP2_nWCtw         91       91     91           91    91    91
# -5VyAi8GR34xmDAgFZTitg        437      437    437          437   437   437
# -9Wf7fUFcwC-3gEBc9iapw        116      116    116          116   116   116
# -AIX1rem_OF-9Et3p_K9Gg        335      335    335          335   335   335
# -CHazLwo2j2G8gWEZN53hA        824      824    824          824   824   824
# ...                           ...      ...    ...          ...   ...   ...
# ztY4uPNUTWMN9LT3L5mD3Q        828      828    828          828   828   828
# zxoDFey10RZK4jG6ylrR3Q         87       87     87           87    87    87
# zy75CWA_oJYEhtXz8OOQsg         94       94     94           94    94    94
# zzin1d1oHi81GuI0ufo1VA        656      656    656          656   656   656
# zzlkjDG9Rv8Jn-vSolMgyw        120      120    120          120   120   120
#
#                         categories  address  postal code  price  text_length
# business_id
# -4P7VlKa9n-TwOP2_nWCtw          91       91           91     91           91
# -5VyAi8GR34xmDAgFZTitg         437      437          437    437          437
# -9Wf7fUFcwC-3gEBc9iapw         116      116          116    116          116
# -AIX1rem_OF-9Et3p_K9Gg         335      335          335    335          335
# -CHazLwo2j2G8gWEZN53hA         824      824          824    824          824
# ...                            ...      ...          ...    ...          ...
# ztY4uPNUTWMN9LT3L5mD3Q         828      828          828    828          828
# zxoDFey10RZK4jG6ylrR3Q          87       87           87     87           87
# zy75CWA_oJYEhtXz8OOQsg          94       94           94     94           94
# zzin1d1oHi81GuI0ufo1VA         656      656          656    656          656
# zzlkjDG9Rv8Jn-vSolMgyw         120      120          120    120          120
#
# [1796 rows x 11 columns]

# %%
df_select.min()
# Out:
# review_id      70
# user id        70
# stars          70
# review_date    70
# text           70
# name           70
# categories     70
# address        70
# postal code    70
# price          70
# text_length    70
# dtype: int64

# %%
df_plus = df_count[df_count.review_id >= 70]
df_plus
# Out:
#                         review_id  user id  stars  review_date  text  name  \
# business_id
# -4P7VlKa9n-TwOP2_nWCtw         91       91     91           91    91    91
# -5VyAi8GR34xmDAgFZTitg        437      437    437          437   437   437
# -9Wf7fUFcwC-3gEBc9iapw        116      116    116          116   116   116
# -AIX1rem_OF-9Et3p_K9Gg        335      335    335          335   335   335
# -CHazLwo2j2G8gWEZN53hA        824      824    824          824   824   824
# ...                           ...      ...    ...          ...   ...   ...
# ztY4uPNUTWMN9LT3L5mD3Q        828      828    828          828   828   828
# zxoDFey10RZK4jG6ylrR3Q         87       87     87           87    87    87
# zy75CWA_oJYEhtXz8OOQsg         94       94     94           94    94    94
# zzin1d1oHi81GuI0ufo1VA        656      656    656          656   656   656
# zzlkjDG9Rv8Jn-vSolMgyw        120      120    120          120   120   120
#
#                         categories  address  postal code  price  text_length
# business_id
# -4P7VlKa9n-TwOP2_nWCtw          91       91           91     91           91
# -5VyAi8GR34xmDAgFZTitg         437      437          437    437          437
# -9Wf7fUFcwC-3gEBc9iapw         116      116          116    116          116
# -AIX1rem_OF-9Et3p_K9Gg         335      335          335    335          335
# -CHazLwo2j2G8gWEZN53hA         824      824          824    824          824
# ...                            ...      ...          ...    ...          ...
# ztY4uPNUTWMN9LT3L5mD3Q         828      828          828    828          828
# zxoDFey10RZK4jG6ylrR3Q          87       87           87     87           87
# zy75CWA_oJYEhtXz8OOQsg          94       94           94     94           94
# zzin1d1oHi81GuI0ufo1VA         656      656          656    656          656
# zzlkjDG9Rv8Jn-vSolMgyw         120      120          120    120          120
#
# [1796 rows x 11 columns]

# %%
df = df[df.business_id.isin(df_plus.index)]

# %%
df['review_date'] = pd.to_datetime(df['review_date'])
# Out:
# /tmp/ipykernel_224043/4256765976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review_date'] = pd.to_datetime(df['review_date'])

# %%
df
# Out:
#                     business_id               review_id  \
# 0        TA1KUSCu8GkWP9w0rmElxw  Gi5LSRmTXoL9Bp4jNGPjLw
# 1        gGvNgShksetPoimyKV8I9Q  egHMQBhFeaLhVyC6w3r0vQ
# 2        ZW7aI5FO_3q_vSzI4_zx-Q  3c4LFWiVUHPDQzAd8uxc3A
# 3        dWBKYjQ3q2v2dOjsfLLxDg  fzEqkhqC0P3feYtEx8vPlw
# 4        IdXHHEUH4ebcxdRxCo3JNw  oNNTEpc2PmB4w_vy9pbsJw
# ...                         ...                     ...
# 1533255  dfL1KYHtcs6YaFVx-nZTdQ  PcIFxlryCtRoHWOqaIPzDg
# 1533256  ybWP67EyI5JrIIX3OrS5Iw  hgBrGer-QIeBpbSaHflGJA
# 1533257  2nEGn1ZfsM_sUelI4JH00Q  8vdn6bPgDTDfPCrLHdYxVQ
# 1533258  2nEGn1ZfsM_sUelI4JH00Q  ciY16xMqVAm2v-bZUGL3VA
# 1533259  _qkEX2cEPXuGmpa_bunJ2Q  WCDbBwtgk69s9TjLcEab8A
#
#                         user id stars         review_date  \
# 0        hn0ZbitvmlHnF--KJGJ6_A   4.0 2011-10-27 14:32:57
# 1        HvpNr0ohHCaVLp014CQrdw   4.0 2015-10-04 05:37:01
# 2        jySmPCkEkJR3cWJlkEs9cw   5.0 2013-08-15 14:47:40
# 3        FPafIu-ul1pFUCM2J-fP_A   1.0 2015-12-20 19:31:34
# 4        s4NgvdIfBH3UQdccWCyARg   3.0 2009-10-13 22:20:10
# ...                         ...   ...                 ...
# 1533255  SMLAMUZuSbGk5wTeaeme8w   5.0 2021-01-08 15:07:20
# 1533256  pa3D36unBCBYEgKDqdng3w   3.0 2019-12-20 14:47:09
# 1533257  5bklKTnJtRKmqVUQEySnoQ   5.0 2020-09-14 22:36:33
# 1533258  hOi1Q3Bs-4xYdwdSj_uweg   5.0 2020-09-08 01:05:03
# 1533259  lHXnu8hjfCQzltV3jYVB7Q   2.0 2020-02-21 00:42:48
#
#                                                       text  \
# 0        I have been here twice and have had really goo...
# 1        Quickly stopped in for a UFC fight. I sat down...
# 2        Definitely 5 stars for the donuts.  Our family...
# 3        This has not been a pleasant experience. Accor...
# 4        'A Bit Embarrassed'  I'm not exactly sure wher...
# ...                                                    ...
# 1533255  okay wow my boyfriend picked this place for br...
# 1533256  BLU Cantina's food and margaritas were delicio...
# 1533257  Ok Cafe is the true definition of comfort food...
# 1533258  Wow, such a lovely spot right off the highway ...
# 1533259  This is my second experience at Salad Express ...
#
#                                           name  \
# 0                         FLIP burger boutique
# 1                                Hudson Grille
# 2        Sub-Base Sandwich Shoppe/Dandy Donuts
# 3                  The BQE Restaurant & Lounge
# 4                                      Rosebud
# ...                                        ...
# 1533255                           Whiskey Bird
# 1533256                            BLU Cantina
# 1533257                                OK Cafe
# 1533258                                OK Cafe
# 1533259                          Salad Express
#
#                                                 categories  \
# 0        Burgers, Specialty Food, Restaurants, Barbeque...
# 1        Venues & Event Spaces, Restaurants, Sports Bar...
# 2        Food, Breakfast & Brunch, Sandwiches, Restaura...
# 3        Soul Food, Restaurants, Southern, Nightlife, L...
# 4        Southern, American (Traditional), American (Ne...
# ...                                                    ...
# 1533255  American (New), Burgers, Asian Fusion, Breakfa...
# 1533256  Latin American, Bars, Music Venues, Nightlife,...
# 1533257  Sandwiches, Restaurants, Breakfast & Brunch, D...
# 1533258  Sandwiches, Restaurants, Breakfast & Brunch, D...
# 1533259                 Salad, American (New), Restaurants
#
#                            address  postal code  price  text_length
# 0              1587 Howell Mill Rd      30318.0    2.0       1621.0
# 1              942 Peachtree St NE      30309.0    2.0       1023.0
# 2        3677 Chamblee Dunwoody Rd      30341.0    1.0        544.0
# 3              262 Edgewood Ave NE      30303.0    2.0        335.0
# 4           1397 N Highland Ave NE      30306.0    2.0       4434.0
# ...                            ...          ...    ...          ...
# 1533255     1409 N Highland Ave NE      30306.0    2.0        764.0
# 1533256       1242 Glenwood Ave SE      30316.0    2.0        712.0
# 1533257   1284 W Paces Ferry Rd NW      30327.0    2.0        187.0
# 1533258   1284 W Paces Ferry Rd NW      30327.0    2.0        265.0
# 1533259         1171 Lavista Rd NE      30324.0    1.0        899.0
#
# [629257 rows x 12 columns]

# %%
df = df.loc[(df['review_date'] > '2008-01-01') & (df['review_date'] <= '2020-01-01')]

# %%
df_count = df.groupby('business_id').count()
df_plus = df_count[df_count.review_id >= 100]
df_plus
# Out:
#                         review_id  user id  stars  review_date  text  name  \
# business_id
# -5VyAi8GR34xmDAgFZTitg        425      425    425          425   425   425
# -AIX1rem_OF-9Et3p_K9Gg        310      310    310          310   310   310
# -CHazLwo2j2G8gWEZN53hA        755      755    755          755   755   755
# -DISJqPp4zcDVw7R-MOjog        186      186    186          186   186   186
# -EzfZm6rTohZdD9tfQaMyA        156      156    156          156   156   156
# ...                           ...      ...    ...          ...   ...   ...
# zpKvO2SOXHV9cxvBm6q4Fg        203      203    203          203   203   203
# zpOcXfa6bbW6AG5L60UL_A        202      202    202          202   202   202
# ztY4uPNUTWMN9LT3L5mD3Q        761      761    761          761   761   761
# zzin1d1oHi81GuI0ufo1VA        613      613    613          613   613   613
# zzlkjDG9Rv8Jn-vSolMgyw        117      117    117          117   117   117
#
#                         categories  address  postal code  price  text_length
# business_id
# -5VyAi8GR34xmDAgFZTitg         425      425          425    425          425
# -AIX1rem_OF-9Et3p_K9Gg         310      310          310    310          310
# -CHazLwo2j2G8gWEZN53hA         755      755          755    755          755
# -DISJqPp4zcDVw7R-MOjog         186      186          186    186          186
# -EzfZm6rTohZdD9tfQaMyA         156      156          156    156          156
# ...                            ...      ...          ...    ...          ...
# zpKvO2SOXHV9cxvBm6q4Fg         203      203          203    203          203
# zpOcXfa6bbW6AG5L60UL_A         202      202          202    202          202
# ztY4uPNUTWMN9LT3L5mD3Q         761      761          761    761          761
# zzin1d1oHi81GuI0ufo1VA         613      613          613    613          613
# zzlkjDG9Rv8Jn-vSolMgyw         117      117          117    117          117
#
# [1404 rows x 11 columns]

# %%
df = df[df.business_id.isin(df_plus.index)]
df
# Out:
#                     business_id               review_id  \
# 0        TA1KUSCu8GkWP9w0rmElxw  Gi5LSRmTXoL9Bp4jNGPjLw
# 1        gGvNgShksetPoimyKV8I9Q  egHMQBhFeaLhVyC6w3r0vQ
# 3        dWBKYjQ3q2v2dOjsfLLxDg  fzEqkhqC0P3feYtEx8vPlw
# 4        IdXHHEUH4ebcxdRxCo3JNw  oNNTEpc2PmB4w_vy9pbsJw
# 5        p2BkIrOuIsxGqtV0lwOZUw  ADPWjsySIpmuOSL07w7kSQ
# ...                         ...                     ...
# 1533234  RewS023eAFmP9AlOcemXkw  kpaEba5kBxkpRd4tywzJpA
# 1533237  u6d48KNDdsjJlCbXyMmbvw  Envps8fOe4hKi-XLMnAitQ
# 1533244  7t8AnQq-LlSJyXhbPNxlrg  4P-CjzncCLDopkdR2IUhbg
# 1533250  r2qrC013gA3soTbtYJyyvg  5F5DnxBLDm1_eWBQiKmGQg
# 1533251  7IuCccysE5EkOzvLajwHqg  VU5XZ1OqeuhRFdeIDJR8hw
#
#                         user id stars         review_date  \
# 0        hn0ZbitvmlHnF--KJGJ6_A   4.0 2011-10-27 14:32:57
# 1        HvpNr0ohHCaVLp014CQrdw   4.0 2015-10-04 05:37:01
# 3        FPafIu-ul1pFUCM2J-fP_A   1.0 2015-12-20 19:31:34
# 4        s4NgvdIfBH3UQdccWCyARg   3.0 2009-10-13 22:20:10
# 5        _soZ9DRjCF7Op7Us8bxSSA   3.0 2014-12-17 19:34:52
# ...                         ...   ...                 ...
# 1533234  9BwYDU22c7Z7hW9jneWTBA   2.0 2019-09-29 02:48:50
# 1533237  IMVZIi7x3d3NIQH1T5MN-Q   5.0 2018-05-14 01:13:42
# 1533244  HToqdBghDzj5TdfqXuE1Rw   4.0 2016-02-26 18:05:31
# 1533250  g95sexGx4huO-AeH7dQuIg   5.0 2019-07-23 21:20:18
# 1533251  hy_vjsKbonfACgqsqRJyaw   3.0 2019-06-17 19:53:57
#
#                                                       text  \
# 0        I have been here twice and have had really goo...
# 1        Quickly stopped in for a UFC fight. I sat down...
# 3        This has not been a pleasant experience. Accor...
# 4        'A Bit Embarrassed'  I'm not exactly sure wher...
# 5        Just had Yalla for lunch today. I work on Krog...
# ...                                                    ...
# 1533234  Ill give you two stars because I used to like ...
# 1533237  3/29/18 (my 33rd birthday) was when I came her...
# 1533244  I didn't want to like it, but I did.  I mean s...
# 1533250  Mi Barrio is the absolute jam. Their tortas ar...
# 1533251  This place is 'A-OK,' but it's not outstanding...
#
#                                 name  \
# 0               FLIP burger boutique
# 1                      Hudson Grille
# 3        The BQE Restaurant & Lounge
# 4                            Rosebud
# 5                              Yalla
# ...                              ...
# 1533234                   Blue India
# 1533237                     Taco Mac
# 1533244          Varasano's Pizzeria
# 1533250                    Mi Barrio
# 1533251     The Little Tart Bakeshop
#
#                                                 categories  \
# 0        Burgers, Specialty Food, Restaurants, Barbeque...
# 1        Venues & Event Spaces, Restaurants, Sports Bar...
# 3        Soul Food, Restaurants, Southern, Nightlife, L...
# 4        Southern, American (Traditional), American (Ne...
# 5        Lebanese, Restaurants, Greek, Mediterranean, M...
# ...                                                    ...
# 1533234               Restaurants, Nightlife, Indian, Bars
# 1533237  Mexican, Tacos, American (New), Beer, Wine & S...
# 1533244                        Pizza, Italian, Restaurants
# 1533250                               Mexican, Restaurants
# 1533251  Food, Desserts, Restaurants, Bakeries, Breakfa...
#
#                                    address  postal code  price  text_length
# 0                      1587 Howell Mill Rd      30318.0    2.0       1621.0
# 1                      942 Peachtree St NE      30309.0    2.0       1023.0
# 3                      262 Edgewood Ave NE      30303.0    2.0        335.0
# 4                   1397 N Highland Ave NE      30306.0    2.0       4434.0
# 5                            99 Krog St NE      30307.0    2.0       1187.0
# ...                                    ...          ...    ...          ...
# 1533234       933 Peachtree St NE, Ste 915      30309.0    2.0        286.0
# 1533237                    100 Techwood Dr      30303.0    2.0        211.0
# 1533244  6000 N Terminal Pkwy, Concourse A      30320.0    2.0        499.0
# 1533250                 571 Memorial Dr SE      30312.0    1.0        225.0
# 1533251                      99 Krog St NE      30307.0    1.0        354.0
#
# [462381 rows x 12 columns]
